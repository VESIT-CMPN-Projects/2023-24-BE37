# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedansh-777/Fetal_Brain_Anomalies/blob/main/Model_Training_Using_YOLOv5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # YOLOv5 Instance Segmentation Tutorial
#
# YOLOv5 supports instance segmentation tasks too. This is the official YOLOv5 instance segmentation notebook tutorial. YOLOv5 is maintained by [Ultralytics](https://github.com/ultralytics/yolov5).
#
# This notebook covers:
#
# *   Inference with out-of-the-box YOLOv5 instance segmentation on COCO-128 Segmentatation
# *  [Training YOLOv5 instance segmentation](https://blog.roboflow.com//train-yolov5-instance-segmentation-custom-dataset) on custom data
#
# *Looking for custom data? Explore over 66M community datasets on [Roboflow Universe](https://universe.roboflow.com).*
#
# This notebook was created with Google Colab. [Click here](https://colab.research.google.com/drive/1JTz7kpmHsg-5qwVz2d2IH3AaenI1tv0N?usp=sharing) to run it.

# %% [markdown]
# # Setup
# Pull in respective libraries to prepare the notebook environment

# %%
# !git clone https://github.com/ultralytics/yolov5.git # clone
# %cd yolov5
# %pip install -r requirements.txt # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %% [markdown]
# # 1. Infer on COCO-128
#
# To demonstrate YOLOv5 instance segmentation, we'll leverage an already trained model. In this case, we'll download the COCO-128 trained models pretrained on COCO-128 using YOLOv5 Utils.
#
# If you'd like to skip to custom trainining, jump to section 3 below.

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-seg' for x in p5]  # segmentation models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5n-seg.pt to weights/yolov5n-seg.pt...
# 100%|██████████| 4.11M/4.11M [00:00<00:00, 75.2MB/s]
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s-seg.pt to weights/yolov5s-seg.pt...
# 100%|██████████| 14.9M/14.9M [00:00<00:00, 71.0MB/s]
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5m-seg.pt to weights/yolov5m-seg.pt...
# 100%|██████████| 42.4M/42.4M [00:00<00:00, 69.2MB/s]
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5l-seg.pt to weights/yolov5l-seg.pt...
# 100%|██████████| 91.9M/91.9M [00:01<00:00, 75.0MB/s]
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5x-seg.pt to weights/yolov5x-seg.pt...
# 100%|██████████| 170M/170M [00:02<00:00, 71.4MB/s]

# %% [markdown]
# Now, we can infer on an example image from the COCO-128 dataset.

# %%
#Download example image
import requests
image_url = "https://i.imgur.com/EbOBS5l.jpg"
img_data = requests.get(image_url).content
with open('zebra.jpg', 'wb') as handler:
    handler.write(img_data)

# %%
#Infer using segment/predict.py
# !python segment/predict.py --weights ./weights/yolov5s-seg.pt --source zebra.jpg
display.Image(filename='runs/predict-seg/exp/zebra.jpg', width=600)
# Out:
# segment/predict: weights=['./weights/yolov5s-seg.pt'], source=zebra.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v6.2-224-g82a5585 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# YOLOv5s-seg summary: 224 layers, 7611485 parameters, 0 gradients, 26.4 GFLOPs
# image 1/1 /content/yolov5/yolov5/zebra.jpg: 448x640 1 zebra, 16.2ms
# Speed: 4.0ms pre-process, 16.2ms inference, 1.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/predict-seg/exp

# %% [markdown]
# ## 2. (Optional) Validate
#
# Use the `segment/val.py` script to run validation for the model. This will show us the model's performance.
#
# First, we need to download COCO-128.

# %%
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco128-seg.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
#   0%|          | 0.00/6.79M [00:00<?, ?B/s]

# %%
# !python segment/val.py --weights yolov5s-seg.pt --data coco128-seg.yaml --img 640
# Out:
# segment/val: data=/content/yolov5/data/coco128-seg.yaml, weights=['yolov5s-seg.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val-seg, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-149-g77dcf55 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.2/yolov5s-seg.pt to yolov5s-seg.pt...
# 100% 14.9M/14.9M [00:00<00:00, 252MB/s]
#
# Fusing layers...
# YOLOv5s-seg summary: 224 layers, 7611485 parameters, 0 gradients, 26.4 GFLOPs
# val: Scanning '/content/datasets/coco128-seg/labels/train2017' images and labels...126 found, 2 missing, 0 empty, 0 corrupt: 100% 128/128 [00:00<00:00, 1216.50it/s]
# val: New cache created: /content/datasets/coco128-seg/labels/train2017.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 4/4 [00:11<00:00,  2.95s/it]
#                    all        128        929      0.709      0.651      0.711      0.487      0.677      0.626      0.661      0.403
# Speed: 2.9ms pre-process, 4.9ms inference, 4.8ms NMS per image at shape (32, 3, 640, 640)
# Results saved to runs/val-seg/exp

# %% [markdown]
# The output shows performance metrics for the COCO-128 validation dataset.

# %% [markdown]
# # 3. Train On Custom Data
#
# To train on custom data, we need to prepare a dataset with custom labels.
#
# To prepare custom data, we'll use [Roboflow](https://roboflow.com). Roboflow enables easy dataset prep with your team, including labeling, formatting into the right export format, deploying, and active learning with a `pip` package.
#
# If you need custom data, there are over 66M open source images from the community on [Roboflow Universe](https://universe.roboflow.com).
#
# (For more guidance, here's a detailed blog on [training YOLOv5 instance segmentation on custom data](https://blog.roboflow.com/train-yolov5-instance-segmentation-custom-dataset).)
#
#
# Create a free Roboflow account, upload your data, and label.
#
# ![](https://robflow-public-assets.s3.amazonaws.com/how-to-train-yolov5-segmentation-annotation.gif)

# %% [markdown]
# ### Load Custom Dataset
#
# Next, we'll export our dataset into the right directory structure for training YOLOv5 segmentation to load into this notebook. Select the `Export` button at the top of the version page, `YOLO v5 Pytorch` type, and `show download code`.
#
# This ensures all our directories are in the right format with the needed data.yaml file:
#
# ```
# dataset
# ├── train
# │   ├── images
# │   │   ├── IMG_123.jpg
# │   └── labels
# │       ├── IMG_123.txt
# ├── valid
# │   ├── images
# │   │   ├── IMG_456.jpg
# │   └── labels
# │       ├── IMG_456.txt
# ├── test
# │   ├── images
# │   │   ├── IMG_789.jpg
# │   └── labels
# │       ├── IMG_789.txt
# ├── data.yaml
# ├── README.roboflow.txt
# ```
#
# ![](https://robflow-public-assets.s3.amazonaws.com/how-to-train-yolov5-segmentation-format.gif)
#
#
# Copy and paste that snippet into the cell below.

# %%
# REPLACE the below with your exported code snippet from above
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XNXw2FYgN16GDs7JaMij")
project = rf.workspace("computer-vision-m75wg").project("fetal-brain-abnormality-classification")
dataset = project.version(2).download("yolov5")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.6-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 1.9 MB/s eta 0:00:00
# Collecting certifi==2022.12.7 (from roboflow)
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 8.9 MB/s eta 0:00:00
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 19.0 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (9.4.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.14.0-py3-none-any.whl (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.0.4)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.42.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.2.0)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from supervision->roboflow) (1.11.2)
# Installing collected packages: python-dotenv, pyparsing, opencv-python-headless, idna, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
#       Successfully uninstalled opencv-python-headless-4.8.0.76
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.7.22
#     Uninstalling certifi-2023.7.22:
#       Successfully uninstalled certifi-2023.7.22
# Successfully installed certifi-2022.12.7 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-1.0.0 roboflow-1.1.6 supervision-0.14.0
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Fetal-brain-abnormality-classification-2 to yolov5pytorch:: 100%|██████████| 44467/44467 [00:01<00:00, 37053.93it/s]
# Extracting Dataset Version Zip to Fetal-brain-abnormality-classification-2 in yolov5pytorch:: 100%|██████████| 2794/2794 [00:00<00:00, 7776.48it/s]

# %% [markdown]
# ### Train On Custom Data 🎉
# Here, we use the `dataset.location` attribute to pass our dataset to the `--data` parameter.
#
# Note: we're training for 100 epochs here. We're also starting training from the pretrained weights. Larger datasets will likely benefit from longer training.

# %%
# !python segment/train.py --img 320 --batch 128 --epochs 100 --data {dataset.location}/data.yaml --weights yolov5s-seg.pt
display.Image(filename=f'runs/train-seg/exp/results.png', width=1200)
# Out:
# segment/train: weights=yolov5s-seg.pt, cfg=, data=/content/yolov5/Fetal-brain-abnormality-classification-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=128, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train-seg, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, mask_ratio=4, no_overlap=False
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir runs/train-seg', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=14
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    437131  models.yolo.Segment                     [14, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], 32, 128, [128, 256, 512]]
# Model summary: 225 layers, 7443275 parameters, 7443275 gradients, 26.0 GFLOPs
#
# Transferred 361/367 items from yolov5s-seg.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 60 weight(decay=0.0), 63 weight(decay=0.001), 63 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov5/Fetal-brain-abnormality-classification-2/train/labels... 974 images, 0 backgrounds, 0 corrupt: 100% 974/974 [00:01<00:00, 763.89it/s]
# train: New cache created: /content/yolov5/Fetal-brain-abnormality-classification-2/train/labels.cache
# val: Scanning /content/yolov5/Fetal-brain-abnormality-classification-2/valid/labels... 357 images, 0 backgrounds, 0 corrupt: 100% 357/357 [00:00<00:00, 599.81it/s]
# val: New cache created: /content/yolov5/Fetal-brain-abnormality-classification-2/valid/labels.cache
#
# AutoAnchor: 5.96 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train-seg/exp2/labels.jpg...
# Image sizes 320 train, 320 val
# Using 2 dataloader workers
# Logging results to runs/train-seg/exp2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        0/99      7.93G     0.1316     0.1758    0.01173    0.07615        143        320: 100% 8/8 [00:24<00:00,  3.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.30s/it]
#                    all        357        381          0          0          0          0          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        1/99      10.8G     0.1296     0.1444    0.01228    0.07497        153        320: 100% 8/8 [00:23<00:00,  2.89s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.31s/it]
#                    all        357        381   0.000131     0.0234   7.71e-05    1.4e-05    7.6e-06    0.00246   4.07e-06   8.14e-07
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        2/99      10.8G     0.1199    0.09624    0.01369    0.07236        131        320: 100% 8/8 [00:18<00:00,  2.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.11s/it]
#                    all        357        381   0.000237     0.0468   0.000197   5.15e-05   2.41e-05    0.00325   1.32e-05   1.32e-06
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        3/99      10.8G      0.102    0.07674    0.01691     0.0693        148        320: 100% 8/8 [00:19<00:00,  2.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.06s/it]
#                    all        357        381   0.000826      0.267    0.00204   0.000524    0.00084      0.187    0.00161   0.000392
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        4/99      10.8G    0.08549    0.06388    0.01895    0.06568        143        320: 100% 8/8 [00:19<00:00,  2.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:08<00:00,  4.48s/it]
#                    all        357        381    0.00133      0.333    0.00569    0.00224    0.00135      0.321    0.00582    0.00147
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        5/99      10.8G    0.07654    0.05655    0.01925    0.06342        140        320: 100% 8/8 [00:19<00:00,  2.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.25s/it]
#                    all        357        381      0.294     0.0363     0.0103     0.0028        0.3     0.0476     0.0138    0.00491
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        6/99      10.8G    0.07333    0.05474    0.01854    0.06249        150        320: 100% 8/8 [00:18<00:00,  2.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.46s/it]
#                    all        357        381      0.367      0.063     0.0116    0.00299      0.373     0.0688      0.017    0.00512
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        7/99      10.8G    0.06732    0.05211    0.01858    0.06114        145        320: 100% 8/8 [00:17<00:00,  2.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.58s/it]
#                    all        357        381      0.376     0.0769     0.0219      0.006      0.382      0.102     0.0283    0.00966
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        8/99      10.8G    0.06596    0.04987    0.01735    0.06077        145        320: 100% 8/8 [00:19<00:00,  2.38s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.17s/it]
#                    all        357        381      0.527     0.0794     0.0288    0.00995      0.533     0.0873     0.0355     0.0131
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#        9/99      10.8G    0.06411    0.04822    0.01724    0.05996        131        320: 100% 8/8 [00:20<00:00,  2.54s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.62s/it]
#                    all        357        381      0.538     0.0912     0.0365     0.0129       0.54     0.0862      0.039     0.0141
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       10/99      10.8G    0.06305    0.04743    0.01696    0.05956        160        320: 100% 8/8 [00:18<00:00,  2.34s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.71s/it]
#                    all        357        381      0.551       0.13     0.0437     0.0154      0.555       0.14     0.0475     0.0219
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       11/99      10.8G    0.06043    0.04629    0.01587    0.05881        134        320: 100% 8/8 [00:18<00:00,  2.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.96s/it]
#                    all        357        381      0.538      0.128      0.052     0.0201      0.535      0.137     0.0548     0.0245
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       12/99      10.8G    0.05902    0.04723    0.01566     0.0586        154        320: 100% 8/8 [00:19<00:00,  2.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.86s/it]
#                    all        357        381      0.478      0.175     0.0581     0.0226      0.479      0.183     0.0628     0.0279
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       13/99      10.8G    0.05653    0.04509    0.01473    0.05663        133        320: 100% 8/8 [00:18<00:00,  2.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.74s/it]
#                    all        357        381        0.5      0.162     0.0657     0.0235      0.499      0.165     0.0711     0.0311
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       14/99      10.8G    0.05735    0.04665    0.01447    0.05595        135        320: 100% 8/8 [00:18<00:00,  2.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.74s/it]
#                    all        357        381      0.659      0.127     0.0978     0.0387      0.659      0.124     0.0966     0.0439
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       15/99      10.8G    0.05539    0.04453    0.01457    0.05414        153        320: 100% 8/8 [00:19<00:00,  2.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.25s/it]
#                    all        357        381      0.785      0.116      0.133     0.0522      0.786      0.121      0.135     0.0608
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       16/99      10.8G    0.05193    0.04352    0.01439    0.05396        145        320: 100% 8/8 [00:19<00:00,  2.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.19s/it]
#                    all        357        381      0.718     0.0865     0.0807     0.0285      0.731     0.0806      0.082      0.035
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       17/99      10.8G    0.05182    0.04186    0.01401    0.05176        139        320: 100% 8/8 [00:17<00:00,  2.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.56s/it]
#                    all        357        381      0.636     0.0876     0.0597     0.0234      0.637     0.0886     0.0598     0.0278
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       18/99      10.8G    0.05016    0.04022    0.01337    0.04996        151        320: 100% 8/8 [00:18<00:00,  2.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.80s/it]
#                    all        357        381      0.683       0.14      0.147     0.0642      0.683      0.137      0.143     0.0697
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       19/99      10.8G    0.04945    0.04055    0.01346     0.0474        158        320: 100% 8/8 [00:19<00:00,  2.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.21s/it]
#                    all        357        381       0.45      0.209       0.14     0.0601      0.453       0.21      0.145     0.0673
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       20/99      10.8G    0.04758     0.0397    0.01309    0.04709        151        320: 100% 8/8 [00:19<00:00,  2.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.82s/it]
#                    all        357        381      0.592      0.147      0.148     0.0623      0.593      0.153      0.148     0.0683
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       21/99      10.8G    0.04711    0.04044    0.01235    0.04553        130        320: 100% 8/8 [00:19<00:00,  2.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.20s/it]
#                    all        357        381      0.434       0.26      0.191     0.0787      0.464      0.266      0.194     0.0871
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       22/99      10.8G    0.04759     0.0391    0.01263    0.04268        147        320: 100% 8/8 [00:18<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.29s/it]
#                    all        357        381      0.796      0.144      0.181     0.0756      0.796      0.144       0.18     0.0889
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       23/99      10.8G    0.04708    0.03765    0.01209    0.04054        140        320: 100% 8/8 [00:17<00:00,  2.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.40s/it]
#                    all        357        381      0.818      0.167      0.209     0.0908      0.813      0.174      0.194      0.104
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       24/99      10.8G    0.04659    0.03768    0.01186    0.03887        136        320: 100% 8/8 [00:17<00:00,  2.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.63s/it]
#                    all        357        381      0.831      0.195      0.227      0.103      0.841      0.201      0.232      0.112
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       25/99      10.8G    0.04559    0.03824    0.01215    0.03826        142        320: 100% 8/8 [00:20<00:00,  2.51s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.99s/it]
#                    all        357        381      0.675      0.238      0.233      0.107      0.835      0.195       0.23      0.113
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       26/99      10.8G    0.04542    0.03686    0.01214    0.03497        141        320: 100% 8/8 [00:18<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.41s/it]
#                    all        357        381      0.781      0.213      0.259      0.103      0.779      0.214      0.266      0.131
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       27/99      10.8G    0.04378    0.03678    0.01199    0.03548        148        320: 100% 8/8 [00:17<00:00,  2.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.74s/it]
#                    all        357        381      0.636      0.297      0.354      0.171      0.639      0.294      0.351      0.181
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       28/99      10.8G    0.04304     0.0377    0.01198     0.0324        131        320: 100% 8/8 [00:17<00:00,  2.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.64s/it]
#                    all        357        381      0.588      0.277      0.284      0.136      0.597       0.28       0.29      0.147
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       29/99      10.8G    0.04295    0.03646    0.01133     0.0312        144        320: 100% 8/8 [00:18<00:00,  2.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.26s/it]
#                    all        357        381      0.663      0.277      0.307      0.137      0.647      0.271        0.3      0.147
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       30/99      10.8G    0.04372    0.03577    0.01134    0.02951        149        320: 100% 8/8 [00:19<00:00,  2.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.63s/it]
#                    all        357        381      0.707      0.345      0.407      0.179      0.837      0.311        0.4        0.2
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       31/99      10.8G    0.04284     0.0355    0.01126    0.02896        158        320: 100% 8/8 [00:18<00:00,  2.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.81s/it]
#                    all        357        381      0.859      0.351      0.477      0.228      0.863      0.355       0.47      0.241
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       32/99      10.8G    0.04181    0.03446    0.01121    0.02784        155        320: 100% 8/8 [00:17<00:00,  2.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.61s/it]
#                    all        357        381      0.628       0.42      0.432      0.204      0.685       0.41      0.438      0.213
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       33/99      10.8G    0.04093    0.03413    0.01103    0.02788        121        320: 100% 8/8 [00:18<00:00,  2.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.35s/it]
#                    all        357        381      0.727      0.452      0.544      0.258       0.74      0.443       0.52      0.263
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       34/99      10.8G    0.04149    0.03496    0.01087    0.02627        149        320: 100% 8/8 [00:20<00:00,  2.56s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.00s/it]
#                    all        357        381      0.738      0.436      0.508      0.246      0.767      0.424      0.505      0.258
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       35/99      10.8G    0.04203    0.03553    0.01141    0.02624        147        320: 100% 8/8 [00:18<00:00,  2.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.42s/it]
#                    all        357        381      0.736      0.484      0.557      0.287      0.638      0.485      0.541      0.292
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       36/99      10.8G    0.04032    0.03354    0.01078    0.02334        121        320: 100% 8/8 [00:17<00:00,  2.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.68s/it]
#                    all        357        381      0.811      0.465       0.56      0.272      0.816      0.469      0.558      0.302
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       37/99      10.8G    0.04055    0.03287    0.01065    0.02273        146        320: 100% 8/8 [00:18<00:00,  2.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.59s/it]
#                    all        357        381      0.603       0.53      0.583      0.283      0.833      0.423       0.57      0.297
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       38/99      10.8G    0.04004    0.03433    0.01084    0.02205        136        320: 100% 8/8 [00:18<00:00,  2.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.97s/it]
#                    all        357        381      0.814      0.454       0.61      0.312      0.804      0.445       0.58      0.321
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       39/99      10.8G     0.0402    0.03282       0.01     0.0218        126        320: 100% 8/8 [00:19<00:00,  2.45s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.25s/it]
#                    all        357        381      0.735       0.52      0.582      0.288      0.738      0.512      0.574      0.318
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       40/99      10.8G    0.04045    0.03299    0.01046    0.02042        139        320: 100% 8/8 [00:17<00:00,  2.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.37s/it]
#                    all        357        381      0.778      0.535       0.64      0.342      0.813       0.52      0.625      0.347
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       41/99      10.8G    0.03876    0.03286    0.01027    0.01921        151        320: 100% 8/8 [00:18<00:00,  2.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.54s/it]
#                    all        357        381      0.766      0.604      0.666      0.368      0.769      0.591      0.654      0.368
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       42/99      10.8G    0.03842    0.03371    0.01057    0.01982        145        320: 100% 8/8 [00:17<00:00,  2.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.87s/it]
#                    all        357        381      0.762      0.592      0.666      0.377      0.755      0.583       0.65      0.368
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       43/99      10.8G    0.03731    0.03268    0.01016    0.01776        142        320: 100% 8/8 [00:18<00:00,  2.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.51s/it]
#                    all        357        381      0.815      0.565       0.65      0.346      0.832      0.566      0.645      0.356
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       44/99      10.8G    0.03907    0.03202    0.01022    0.01892        142        320: 100% 8/8 [00:20<00:00,  2.51s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.62s/it]
#                    all        357        381      0.822      0.677      0.734        0.4      0.805      0.671      0.727      0.395
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       45/99      10.8G     0.0385    0.03257    0.01046    0.01709        141        320: 100% 8/8 [00:18<00:00,  2.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.38s/it]
#                    all        357        381      0.779      0.633      0.666      0.369      0.778      0.634      0.665      0.375
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       46/99      10.8G     0.0378    0.03225    0.01007    0.01586        152        320: 100% 8/8 [00:17<00:00,  2.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.64s/it]
#                    all        357        381      0.843      0.643      0.724      0.409      0.836      0.624      0.702      0.391
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       47/99      10.8G    0.03715    0.03241    0.01008    0.01571        138        320: 100% 8/8 [00:17<00:00,  2.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.81s/it]
#                    all        357        381      0.873      0.681      0.772       0.42      0.862      0.672      0.755       0.41
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       48/99      10.8G    0.03753    0.03173    0.01008    0.01476        138        320: 100% 8/8 [00:19<00:00,  2.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.78s/it]
#                    all        357        381      0.825      0.699      0.776      0.399      0.824      0.692      0.769      0.406
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       49/99      10.8G    0.03698    0.03144   0.009634     0.0137        144        320: 100% 8/8 [00:19<00:00,  2.49s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.36s/it]
#                    all        357        381      0.871      0.694      0.782       0.43      0.868      0.687      0.781      0.411
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       50/99      10.8G      0.037     0.0314   0.009766    0.01323        142        320: 100% 8/8 [00:17<00:00,  2.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.47s/it]
#                    all        357        381       0.85      0.656      0.759      0.438      0.823       0.67      0.754      0.423
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       51/99      10.8G     0.0359    0.03073    0.01001    0.01339        142        320: 100% 8/8 [00:18<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.47s/it]
#                    all        357        381      0.856      0.677      0.773      0.453      0.847       0.67      0.756      0.423
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       52/99      10.8G    0.03541    0.03116    0.00956    0.01291        132        320: 100% 8/8 [00:18<00:00,  2.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.27s/it]
#                    all        357        381      0.876      0.697      0.788      0.445      0.866      0.689      0.772       0.44
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       53/99      10.8G    0.03536    0.03098   0.009406     0.0126        147        320: 100% 8/8 [00:19<00:00,  2.48s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:08<00:00,  4.49s/it]
#                    all        357        381      0.851      0.609      0.724      0.418       0.84        0.6      0.709        0.4
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       54/99      10.8G    0.03467     0.0303   0.009222    0.01184        140        320: 100% 8/8 [00:19<00:00,  2.42s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.52s/it]
#                    all        357        381      0.851      0.644      0.757      0.446      0.857       0.65      0.761      0.427
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       55/99      10.8G    0.03642    0.03075   0.009609    0.01247        145        320: 100% 8/8 [00:18<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.44s/it]
#                    all        357        381      0.782      0.689      0.769      0.446      0.782      0.686      0.769      0.434
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       56/99      10.8G    0.03404    0.03019   0.009422     0.0117        138        320: 100% 8/8 [00:18<00:00,  2.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.55s/it]
#                    all        357        381      0.894       0.69      0.815      0.497      0.895       0.69      0.809      0.468
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       57/99      10.8G    0.03417    0.03101   0.009606    0.01144        142        320: 100% 8/8 [00:19<00:00,  2.41s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.12s/it]
#                    all        357        381      0.904      0.712      0.851        0.5      0.881       0.69      0.821      0.464
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       58/99      10.8G    0.03433     0.0292   0.009134    0.01198        142        320: 100% 8/8 [00:18<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.82s/it]
#                    all        357        381      0.912       0.71      0.801      0.475       0.91      0.707      0.795      0.456
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       59/99      10.8G      0.034    0.02986   0.009413    0.01078        152        320: 100% 8/8 [00:19<00:00,  2.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.13s/it]
#                    all        357        381      0.901      0.744      0.826      0.472      0.896      0.738       0.82      0.474
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       60/99      10.8G    0.03406    0.02971   0.009447     0.0102        152        320: 100% 8/8 [00:18<00:00,  2.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.76s/it]
#                    all        357        381      0.931      0.744      0.814      0.479      0.926      0.739      0.805      0.465
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       61/99      10.8G    0.03279    0.02986   0.009393   0.009684        160        320: 100% 8/8 [00:18<00:00,  2.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.48s/it]
#                    all        357        381       0.96      0.728      0.806      0.466      0.953      0.721      0.797      0.446
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       62/99      10.8G    0.03294     0.0295   0.009345    0.01002        146        320: 100% 8/8 [00:18<00:00,  2.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.54s/it]
#                    all        357        381      0.901      0.729      0.841      0.504      0.899      0.728      0.836       0.48
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       63/99      10.8G    0.03248    0.02957   0.009405   0.009467        155        320: 100% 8/8 [00:19<00:00,  2.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.69s/it]
#                    all        357        381       0.93       0.74       0.86      0.505      0.933      0.743      0.864      0.483
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       64/99      10.8G    0.03271    0.02954    0.00902   0.009785        155        320: 100% 8/8 [00:18<00:00,  2.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.13s/it]
#                    all        357        381      0.941      0.749      0.857      0.521      0.941      0.749      0.848      0.491
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       65/99      10.8G    0.03216    0.02934   0.008865   0.008936        144        320: 100% 8/8 [00:18<00:00,  2.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.48s/it]
#                    all        357        381      0.936      0.752      0.903      0.534      0.929      0.746       0.89       0.51
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       66/99      10.8G    0.03184    0.02912   0.008971   0.008081        145        320: 100% 8/8 [00:18<00:00,  2.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.45s/it]
#                    all        357        381      0.914      0.752      0.862      0.509      0.918      0.756      0.867      0.491
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       67/99      10.8G    0.03113    0.02889   0.009035   0.008407        175        320: 100% 8/8 [00:17<00:00,  2.13s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.28s/it]
#                    all        357        381      0.911      0.771      0.867      0.545      0.911      0.771      0.863      0.503
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       68/99      10.8G    0.03122    0.02886    0.00893   0.008781        146        320: 100% 8/8 [00:18<00:00,  2.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.70s/it]
#                    all        357        381      0.833      0.846      0.942      0.544      0.827      0.839      0.932      0.506
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       69/99      10.8G    0.03123    0.02894   0.008969   0.007662        134        320: 100% 8/8 [00:18<00:00,  2.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.10s/it]
#                    all        357        381      0.848      0.837      0.911      0.551      0.847      0.836      0.908      0.513
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       70/99      10.8G    0.03049     0.0292    0.00878   0.007772        129        320: 100% 8/8 [00:19<00:00,  2.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.71s/it]
#                    all        357        381      0.882      0.793      0.922      0.571       0.88      0.792      0.913      0.522
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       71/99      10.8G    0.03035    0.02831   0.008743   0.008636        145        320: 100% 8/8 [00:18<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.37s/it]
#                    all        357        381      0.883       0.82      0.936      0.552      0.877      0.812      0.927      0.522
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       72/99      10.8G    0.03023    0.02921   0.008821    0.00745        145        320: 100% 8/8 [00:17<00:00,  2.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.70s/it]
#                    all        357        381      0.909      0.836      0.939      0.588      0.901      0.829      0.925      0.512
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       73/99      10.8G    0.02948    0.02799   0.008737   0.008163        136        320: 100% 8/8 [00:17<00:00,  2.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.35s/it]
#                    all        357        381      0.784      0.878      0.897      0.522      0.783      0.876      0.895      0.491
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       74/99      10.8G    0.02957    0.02856    0.00844   0.007679        146        320: 100% 8/8 [00:18<00:00,  2.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.42s/it]
#                    all        357        381       0.93      0.747      0.861      0.543      0.936      0.753      0.859      0.496
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       75/99      10.8G    0.02976    0.02816   0.008497   0.007622        141        320: 100% 8/8 [00:18<00:00,  2.30s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.05s/it]
#                    all        357        381      0.883      0.855      0.938      0.549       0.87      0.839      0.919      0.489
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       76/99      10.8G    0.02916    0.02734   0.008541   0.007099        149        320: 100% 8/8 [00:19<00:00,  2.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.59s/it]
#                    all        357        381       0.86      0.858       0.94      0.575       0.85      0.847      0.927       0.52
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       77/99      10.8G    0.02854    0.02729   0.008389   0.006431        133        320: 100% 8/8 [00:18<00:00,  2.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.97s/it]
#                    all        357        381      0.804      0.903      0.904      0.538      0.796      0.895      0.895      0.499
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       78/99      10.8G     0.0288    0.02775   0.008318   0.007492        136        320: 100% 8/8 [00:18<00:00,  2.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.47s/it]
#                    all        357        381      0.841        0.9      0.936      0.573      0.841      0.901      0.933      0.517
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       79/99      10.8G    0.02867    0.02787   0.008265    0.00634        143        320: 100% 8/8 [00:18<00:00,  2.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.28s/it]
#                    all        357        381      0.863      0.877      0.915      0.546       0.86      0.871      0.907      0.508
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       80/99      10.8G    0.02841    0.02822   0.008488   0.006663        142        320: 100% 8/8 [00:18<00:00,  2.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.42s/it]
#                    all        357        381      0.888      0.868      0.908      0.551      0.889      0.871      0.913       0.51
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       81/99      10.8G    0.02759     0.0273   0.008173   0.006138        151        320: 100% 8/8 [00:18<00:00,  2.27s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.54s/it]
#                    all        357        381       0.84      0.911      0.935       0.56      0.836      0.905      0.927      0.518
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       82/99      10.8G     0.0279     0.0276   0.008325   0.005548        153        320: 100% 8/8 [00:19<00:00,  2.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.02s/it]
#                    all        357        381      0.915      0.841      0.942      0.574      0.911      0.837       0.94      0.514
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       83/99      10.8G    0.02685    0.02717   0.008176   0.005965        146        320: 100% 8/8 [00:19<00:00,  2.38s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.85s/it]
#                    all        357        381      0.825      0.923      0.941       0.57      0.823      0.918      0.935      0.516
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       84/99      10.8G    0.02762     0.0281   0.008272   0.005844        149        320: 100% 8/8 [00:19<00:00,  2.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.47s/it]
#                    all        357        381      0.932      0.851      0.948      0.565      0.932      0.851      0.947      0.541
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       85/99      10.8G    0.02761    0.02739   0.008275    0.00556        147        320: 100% 8/8 [00:17<00:00,  2.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.45s/it]
#                    all        357        381      0.861      0.937       0.95      0.575      0.859      0.934      0.948      0.533
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       86/99      10.8G    0.02717    0.02723   0.007995   0.005448        144        320: 100% 8/8 [00:18<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.32s/it]
#                    all        357        381      0.932      0.843      0.881      0.542      0.894       0.92      0.952      0.524
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       87/99      10.8G    0.02654    0.02681   0.008045   0.005212        132        320: 100% 8/8 [00:17<00:00,  2.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.54s/it]
#                    all        357        381      0.936      0.833      0.889      0.552       0.93      0.826      0.887      0.518
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       88/99      10.8G    0.02663     0.0273   0.008358   0.004968        153        320: 100% 8/8 [00:18<00:00,  2.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.47s/it]
#                    all        357        381       0.93      0.845      0.887      0.558      0.923      0.838       0.88      0.516
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       89/99      10.8G     0.0262    0.02659   0.007928   0.005286        141        320: 100% 8/8 [00:19<00:00,  2.39s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.73s/it]
#                    all        357        381      0.931      0.838      0.909      0.561       0.93      0.837      0.909      0.523
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       90/99      10.8G    0.02586    0.02635   0.008106    0.00477        138        320: 100% 8/8 [00:18<00:00,  2.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.35s/it]
#                    all        357        381      0.876      0.927      0.927      0.594      0.876      0.927      0.928      0.546
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       91/99      10.8G     0.0259    0.02707   0.007889   0.004765        140        320: 100% 8/8 [00:17<00:00,  2.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.57s/it]
#                    all        357        381      0.904      0.933      0.959      0.609      0.901       0.93      0.959      0.557
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       92/99      10.8G    0.02594    0.02754   0.008387   0.004707        147        320: 100% 8/8 [00:17<00:00,  2.23s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.36s/it]
#                    all        357        381      0.872      0.953       0.96      0.616      0.868      0.947      0.957      0.549
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       93/99      10.8G    0.02498    0.02619   0.007682   0.004712        146        320: 100% 8/8 [00:17<00:00,  2.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.36s/it]
#                    all        357        381      0.901      0.942      0.962      0.638      0.897      0.936      0.957       0.55
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       94/99      10.8G     0.0248    0.02596   0.007829   0.004521        142        320: 100% 8/8 [00:17<00:00,  2.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:11<00:00,  5.57s/it]
#                    all        357        381      0.871      0.936      0.956      0.601      0.872      0.937      0.961      0.539
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       95/99      10.8G    0.02459    0.02495   0.007573   0.003899        145        320: 100% 8/8 [00:18<00:00,  2.29s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.96s/it]
#                    all        357        381      0.865      0.935      0.956      0.604      0.861      0.931      0.953      0.539
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       96/99      10.8G    0.02464    0.02624   0.007744   0.004509        149        320: 100% 8/8 [00:19<00:00,  2.48s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:09<00:00,  4.64s/it]
#                    all        357        381      0.946      0.828      0.905      0.582      0.934      0.821        0.9      0.526
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       97/99      10.8G    0.02396     0.0258   0.007738   0.004685        139        320: 100% 8/8 [00:18<00:00,  2.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.30s/it]
#                    all        357        381      0.834      0.938      0.949      0.603      0.837      0.941       0.95      0.545
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       98/99      10.8G    0.02449     0.0264   0.007637   0.003931        156        320: 100% 8/8 [00:18<00:00,  2.32s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.37s/it]
#                    all        357        381      0.872      0.936      0.951      0.606      0.869       0.93      0.948      0.542
#
#       Epoch    GPU_mem   box_loss   seg_loss   obj_loss   cls_loss  Instances       Size
#       99/99      10.8G    0.02393    0.02584   0.007845    0.00475        148        320: 100% 8/8 [00:18<00:00,  2.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:10<00:00,  5.45s/it]
#                    all        357        381      0.861      0.925      0.948      0.613      0.858      0.922      0.949       0.55
#
# 100 epochs completed in 0.845 hours.
# Optimizer stripped from runs/train-seg/exp2/weights/last.pt, 15.1MB
# Optimizer stripped from runs/train-seg/exp2/weights/best.pt, 15.1MB
#
# Validating runs/train-seg/exp2/weights/best.pt...
# Fusing layers...
# Model summary: 165 layers, 7433483 parameters, 0 gradients, 25.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 2/2 [00:07<00:00,  3.64s/it]
#                    all        357        381      0.901      0.942      0.962      0.637      0.896      0.935      0.957       0.55
# anold chiari malformation        357         10      0.935          1      0.995      0.679      0.935          1      0.995      0.505
#         arachnoid cyst        357         22          1      0.968      0.995      0.662          1      0.968      0.995       0.62
#  cerebellah hypoplasia        357         32      0.844      0.845      0.897      0.633      0.875      0.876      0.943      0.583
#         cisterna magna        357         10      0.789          1      0.977      0.599       0.71        0.9      0.887      0.479
#          colphocephaly        357         29      0.802      0.724      0.842      0.438      0.802      0.724      0.842      0.429
#          encephalocele        357         37          1      0.915      0.953      0.652          1      0.915      0.953      0.631
#      holoprosencephaly        357          4      0.862          1      0.995      0.846      0.862          1      0.995      0.647
#          hydracenphaly        357          8       0.91          1      0.995      0.765       0.91          1      0.995      0.728
# intracranial hemorrdge        357         18          1       0.94      0.972      0.505          1       0.94      0.972      0.545
#     intracranial tumor        357          1      0.781          1      0.995      0.697      0.781          1      0.995      0.298
#  mild ventriculomegaly        357         72      0.956      0.907      0.935       0.56      0.956      0.907      0.942      0.502
# moderate ventriculomegaly        357         71       0.79      0.956      0.951      0.646       0.79      0.956      0.951      0.599
#           polencephaly        357         32          1      0.968      0.988      0.588          1      0.968      0.988      0.549
# severe ventriculomegaly        357         35      0.944      0.961      0.972      0.653      0.926      0.943      0.943      0.576
# Results saved to runs/train-seg/exp2

# %% [markdown]
# Above we see training plots for our custom trained model. This plot along with other detailed results and sample predictions are all automatically generated and stored in the `runs` folder. See `runs/train-seg/exp`.

# %% [markdown]
# ### Validate Your Custom Model
#
# Repeat step 2 from above to test and validate your custom model.

# %%
# !python segment/val.py --weights runs/train-seg/exp2/weights/best.pt --data {dataset.location}/data.yaml --img 320
# Out:
# segment/val: data=/content/yolov5/Fetal-brain-abnormality-classification-2/data.yaml, weights=['runs/train-seg/exp2/weights/best.pt'], batch_size=32, imgsz=320, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val-seg, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 165 layers, 7433483 parameters, 0 gradients, 25.8 GFLOPs
# val: Scanning /content/yolov5/Fetal-brain-abnormality-classification-2/valid/labels.cache... 357 images, 0 backgrounds, 0 corrupt: 100% 357/357 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 12/12 [00:07<00:00,  1.64it/s]
#                    all        357        381      0.901      0.942      0.962      0.637      0.894      0.933      0.953      0.542
# anold chiari malformation        357         10      0.935          1      0.995      0.679      0.935          1      0.995      0.514
#         arachnoid cyst        357         22          1      0.969      0.995      0.666          1      0.969      0.995      0.641
#  cerebellah hypoplasia        357         32      0.844      0.844      0.899      0.633      0.844      0.844      0.899      0.541
#         cisterna magna        357         10      0.789          1      0.977      0.599       0.71        0.9      0.887      0.453
#          colphocephaly        357         29      0.802      0.724      0.842      0.438      0.802      0.724      0.842      0.412
#          encephalocele        357         37          1      0.915      0.953      0.652          1      0.915      0.953      0.636
#      holoprosencephaly        357          4      0.863          1      0.995      0.846      0.863          1      0.995      0.647
#          hydracenphaly        357          8      0.911          1      0.995      0.757      0.911          1      0.995      0.688
# intracranial hemorrdge        357         18          1      0.941      0.972      0.505          1      0.941      0.972      0.506
#     intracranial tumor        357          1      0.784          1      0.995      0.697      0.784          1      0.995      0.398
#  mild ventriculomegaly        357         72      0.956      0.907      0.935      0.563      0.956      0.907      0.934       0.48
# moderate ventriculomegaly        357         71       0.79      0.956      0.951      0.642       0.79      0.956      0.951      0.585
#           polencephaly        357         32          1      0.968      0.988      0.588          1      0.968      0.988      0.521
# severe ventriculomegaly        357         35      0.944      0.961      0.972       0.65      0.926      0.943      0.943      0.567
# Speed: 0.1ms pre-process, 3.6ms inference, 2.6ms NMS per image at shape (32, 3, 320, 320)
# Results saved to runs/val-seg/exp3

# %% [markdown]
# ### Infer With Your Custom Model

# %%
import os
#Get the path of an image from the test or validation set
if os.path.exists(os.path.join(dataset.location, "test")):
  split_path = os.path.join(dataset.location, "test", "images")
else:
  split_path = os.path.join(dataset.location, "valid", "images")
example_image_name = os.listdir(split_path)[0]
example_image_path = os.path.join(split_path, example_image_name)

#Infer
# !python segment/predict.py --img 320 --weights runs/train-seg/exp/weights/best.pt --source {example_image_path}
display.Image(filename=f'runs/predict-seg/exp3/{example_image_name}', width=600)
# Out:
# segment/predict: weights=['runs/train-seg/exp/weights/best.pt'], source=/content/yolov5/Fetal-brain-abnormality-classification-2/test/images/mild-ventriculomegaly-26c_aug_0_png_jpg.rf.d535da8543e6a8d1f52eccb5b8300e61.jpg, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 165 layers, 7401119 parameters, 0 gradients, 25.7 GFLOPs
# image 1/1 /content/yolov5/Fetal-brain-abnormality-classification-2/test/images/mild-ventriculomegaly-26c_aug_0_png_jpg.rf.d535da8543e6a8d1f52eccb5b8300e61.jpg: 320x320 1 1, 6.4ms
# Speed: 0.3ms pre-process, 6.4ms inference, 82.8ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/predict-seg/exp4

# %%
#Infer
# !python segment/predict.py --img 320 --weights runs/train-seg/exp2/weights/best.pt --source /content/yolov5/runs/predict-seg/exp6/cere.png
# Out:
# segment/predict: weights=['runs/train-seg/exp2/weights/best.pt'], source=/content/yolov5/runs/predict-seg/exp6/cere.png, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 165 layers, 7433483 parameters, 0 gradients, 25.8 GFLOPs
# image 1/1 /content/yolov5/runs/predict-seg/exp6/cere.png: 256x320 (no detections), 47.8ms
# Speed: 0.4ms pre-process, 47.8ms inference, 22.0ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/predict-seg/exp10

# %%
display.Image(filename=f'runs/predict-seg/exp10/cere.png', width=600)

# %%
# !git clone https://github.com/ultralytics/yolov5.git # clone
# %cd yolov5
# %pip install -r requirements.txt # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)
# segment/predict: weights=['runs/train-seg/exp2/weights/best.pt'], source=/content/yolov5/runs/predict-seg/exp6/cere.png, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Traceback (most recent call last):
#   File "/content/yolov5/yolov5/segment/predict.py", line 285, in <module>
#     main(opt)
#   File "/content/yolov5/yolov5/segment/predict.py", line 280, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/yolov5/yolov5/segment/predict.py", line 102, in run
#     model = DetectMultiBackend(weights, device=device, dnn=dnn, data=data, fp16=half)
#   File "/content/yolov5/yolov5/models/common.py", line 356, in __init__
#     model = attempt_load(weights if isinstance(weights, list) else w, device=device, inplace=True, fuse=fuse)
#   File "/content/yolov5/yolov5/models/experimental.py", line 79, in attempt_load
#     ckpt = torch.load(attempt_download(w), map_location='cpu')  # load
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 791, in load
#     with _open_file_like(f, 'rb') as opened_file:
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 271, in _open_file_like
#     return _open_file(name_or_buffer, mode)
#   File "/usr/local/lib/python3.10/dist-packages/torch/serialization.py", line 252, in __init__
#     super().__init__(open(name, mode))
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/train-seg/exp2/weights/best.pt'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-4fc432433043> in <cell line: 11>()
#       9 #Infer
#      10 get_ipython().system('python segment/predict.py --img 320 --weights runs/train-seg/exp2/weights/best.pt --source /content/yolov5/runs/predict-seg/exp6/cere.png')
# ---> 11 display.Image(filename=f'runs/predict-seg/exp10/cere.png', width=600)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in reload(self)
#    1261         """Reload the raw data from file or URL."""
#    1262         if self.embed:
# -> 1263             super(Image,self).reload()
#    1264             if self.retina:
#    1265                 self._retina_shape()
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in reload(self)
#     660         """Reload the raw data from file or URL."""
#     661         if self.filename is not None:
# --> 662             with open(self.filename, self._read_flags) as f:
#     663                 self.data = f.read()
#     664         elif self.url is not None:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs/predict-seg/exp10/cere.png'

# %%
#Infer
# !python segment/predict.py --img 320 --weights /content/yolov5/runs/train-seg/exp2/weights/best.pt --source /content/yolov5/runs/predict-seg/exp6/cere.png
# Out:
# segment/predict: weights=['/content/yolov5/runs/train-seg/exp2/weights/best.pt'], source=/content/yolov5/runs/predict-seg/exp6/cere.png, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v7.0-218-g9e97ac3 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 165 layers, 7433483 parameters, 0 gradients, 25.8 GFLOPs
# image 1/1 /content/yolov5/runs/predict-seg/exp6/cere.png: 256x320 (no detections), 47.0ms
# Speed: 0.3ms pre-process, 47.0ms inference, 20.4ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/predict-seg/exp5

# %%
display.Image(filename=f'runs/predict-seg/exp5/cere.png', width=600)

# %% [markdown]
# The image above shows the resulting prediction overlayed on the input image.

# %% [markdown]
# ## (OPTIONAL) Improve Our Model with Active Learning
#
# Now that we've trained our model once, we will want to continue to improve its performance. Improvement is largely dependent on improving our dataset.
#
# We can programmatically upload example failure images back to our custom dataset based on conditions (like seeing an underrpresented class or a low confidence score) using the same `pip` package.

# %%
#Prepare Our Example Image Directory
#To run on your own images, replace the directory on the line below with a
#directory you provide (by uploading to the colab environment, for example)
example_image_dir = "../example_images"

#We are going to download example images from the web for the purposes of this
#demo. These images are relevant to the ASL Poly dataset. Skip the rest of this
#cell if you are providing your own example image directory.
os.makedirs(example_image_dir, exist_ok=True)
image_links = [
    "https://i.imgur.com/rFsDnHC.jpg",
    "https://i.imgur.com/aEcceXm.jpg",
    "https://i.imgur.com/s4N63fx.jpg",
    ]

for i,link in enumerate(image_links):
  img_data = requests.get(link).content
  with open(os.path.join(example_image_dir,f'example_{i}.jpg'), 'wb') as handler:
    handler.write(img_data)

# %%
#Infer On Directory
# !python segment/predict.py --img 320 --weights runs/train-seg/exp/weights/best.pt --source {example_image_dir} --save-txt --save-conf
# Out:
# segment/predict: weights=['runs/train-seg/exp/weights/best.pt'], source=../example_images, data=data/coco128.yaml, imgsz=[320, 320], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/predict-seg, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# YOLOv5 🚀 v6.2-149-g77dcf55 Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 165 layers, 7465847 parameters, 0 gradients, 25.9 GFLOPs
# image 1/3 /content/example_images/example_0.jpg: 320x320 1 L, 1 Y, 8.2ms
# image 2/3 /content/example_images/example_1.jpg: 320x320 1 G, 1 I, 8.7ms
# image 3/3 /content/example_images/example_2.jpg: 320x320 1 H, 6.9ms
# Speed: 0.3ms pre-process, 8.0ms inference, 1.0ms NMS per image at shape (1, 3, 320, 320)
# Results saved to runs/predict-seg/exp3
# 3 labels saved to runs/predict-seg/exp3/labels

# %%
#Read Results Files and Conditionally Upload

#If my model has a confidence of less than 80% for a prediction, let's help it
#out by uploading this image back to our dataset. Then we can add a ground truth
#label to it so that it will be included in our next training run and future
#prediction results will improve.
MIN_CONF_THRESHOLD = 0.8

for i,txt_file in enumerate(os.listdir("runs/predict-seg/exp3/labels")):
  with open(os.path.join("runs/predict-seg/exp3/labels",txt_file), 'r') as fid:
    for line in fid:
      label, x1, y1, x2, y2, conf = line.split(" ")
      conf = float(conf)
      if conf < MIN_CONF_THRESHOLD:
        print(f"Image has a low confidence prediction, uploading to project: example_{i}.jpg")
        #Upload via Roboflow pip package
        project.upload(os.path.join(example_image_dir,f'example_{i}.jpg'))
        break
# Out:
# Image has a low confidence prediction, uploading to project: example_0.jpg
# Image has a low confidence prediction, uploading to project: example_1.jpg
# Image has a low confidence prediction, uploading to project: example_2.jpg
